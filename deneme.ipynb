# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\MSI\Desktop\aracınıBulDataScience\carsGuncel.csv")

# %%
df
# Out:
#                                                   baslik  \
# 0      2022 MEGANE 1.3 TCE 140 HP JOY COMFORT EDC SER...
# 1      2022 SKODA OCTAVİA 1.0 E-TEC ELİTE DSG SERVİS ...
# 2                 Sahibinden HATASIZ BOYASIZ Peugeot 207
# 3      BEY CLASS'TAN AUDİ A4 QUATRO S-TRONİC 177 HP D...
# 4      BEY CLASS'TAN BMW 520İ/LONG/HAYALET//NBT/K ISI...
# ...                                                  ...
# 52251         ÖZKAN OTOMOTİV DEN 1993 CONCORT 2.0 LPG LI
# 52252       KURT OTOMOTİV'den TRAMERSİZ HATASIZ PANAMERA
# 52253            ÖZKAN OTOMOTİV DEN 2011 CLIO 1.4 LPG LI
# 52254   ÖZKAN OTOMOTİV DEN 1987 RENULT BAKIMLI MASRAFSIZ
# 52255  ÖZKAN OTOMOTİV DEN 2001 BMW 520 İ OTOMATIK SAN...
#
#                              konum         fiyat      ilan_tarihi    marka  \
# 0          Yeni Mh. Sarıçam, Adana  1.169.000 TL  21 Ağustos 2025  Renault
# 1          Yeni Mh. Sarıçam, Adana  1.520.000 TL  21 Ağustos 2025    Skoda
# ...

# %%
df_total=pd.read_csv("merged_cars_data.csv")
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_16820\4041331843.py:1: DtypeWarning: Columns (2,10,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_total=pd.read_csv("merged_cars_data.csv")

# %%
df_total
# Out:
#                                              ilanBasligi  \
# 0      2016 AUDİ A3 SPORTBACK 1.0 TFSI BOYASIZ/DEĞİŞE...
# 1      2018 AUDİ A6 2.0 TDI QUATTRO SUNROOF MATRİX VA...
# 2           Sahibinden Audi A4 Sedan 1.8 TFSI 2011 Model
# 3      2016 AUDI A3 AMBİENTE *CAM TAVAN LED XENON HIZ...
# 4      Sahibinden Audi A3 Sportback 1.6 TDI S-Line 20...
# ...                                                  ...
# 58926         ÖZKAN OTOMOTİV DEN 1993 CONCORT 2.0 LPG LI
# 58927       KURT OTOMOTİV'den TRAMERSİZ HATASIZ PANAMERA
# 58928            ÖZKAN OTOMOTİV DEN 2011 CLIO 1.4 LPG LI
# 58929   ÖZKAN OTOMOTİV DEN 1987 RENULT BAKIMLI MASRAFSIZ
# 58930  ÖZKAN OTOMOTİV DEN 2001 BMW 520 İ OTOMATIK SAN...
#
#                              adres              il    fiyat(TRY)      ilanID  \
# 0             Aşağısoku Mh. Merkez            Bolu  1.169.000 TL  27812680.0
# 1          Güneşevler Mh. Altındağ          Ankara  2.450.000 TL  28816234.0
# ...

# %%
df_total["marka"].unique()
# Out:
# array(['Audi', 'BMW', 'Fiat', 'Ford', 'Hyundai', 'Opel', 'Peugeot',
#        'Renault', 'Toyota', 'Volkswagen', 'DS Automobiles', 'Skoda',
#        'Mercedes - Benz', 'Honda', 'Citroen', 'Volvo', 'Dacia', 'Tofaş',
#        'Lancia', 'Suzuki', 'Alfa Romeo', 'Geely', 'Tesla', 'MINI',
#        'Nissan', 'Kia', 'Mazda', 'Chevrolet', 'Seat', 'Daihatsu', 'Tata',
#        'Lada', 'Bentley', 'Porsche', 'Ferrari', 'Aston Martin',
#        'Rolls-Royce', 'Dodge', 'Mitsubishi', 'Smart', 'Mini', 'Jaguar',
#        'Subaru', 'Daewoo', 'Proton', 'Rover', 'Cupra', 'Saab', 'Maserati',
#        'BYD', 'Cadillac', 'Chrysler', 'Chery', 'Nieve', 'Ikco',
#        'Regal Raptor', 'Mercury', 'Volta', 'MG', 'Infiniti', 'Anadol'],
#       dtype=object)

# %%
df_total[(df_total["marka"]=="Alfa Romeo") & (df_total["il"]=="İstanbul")]
# Out:
#                                         ilanBasligi                    adres  \
# 6106  Sahibinden Alfa Romeo Spider 3.0V6 1996 Model      Velibaba Mh. Pendik
# 6635   2004 ALFA ROMEO 147 1.6 T. Spark Progression  Zümrütevler Mh. Maltepe
#
#             il    fiyat(TRY)      ilanID     ilanTarihi       marka    seri  \
# 6106  İstanbul  1.200.000 TL  29044087.0  17 Nisan 2025  Alfa Romeo  Spider
# 6635  İstanbul    266.500 TL  29022366.0  16 Nisan 2025  Alfa Romeo     147
#
#                    model kilometre(Km)  ...     kasaTipi   renk  \
# 6106              2.0 TS        1996.0  ...       Cabrio  Siyah
# 6635  1.6 TS Progression        2004.0  ...  Hatchback/3    NaN
#
#        motorHacmi(Cc) motorGucu(HP)    cekisTipi  \
# 6106  2501 - 3000 cm3  176 - 200 HP  Önden Çekiş
# 6635          1598 cc        119 hp  Önden Çekiş
#
#                                         boyaParcaDurumu       takasUygunluk  \
# ...
